# %% [markdown]
# # 02 — Time-Series Processing
#
# Process a time-series of spectra and produce a NetCDF with Es, modeled Rrs and Rg.
# This notebook mirrors the `examples/run_timeseries.py` wrapper but in an interactive form.

# %%
# ruff: noqa: E402
import sys
import numpy as np
import lmfit as lm
import matplotlib.pyplot as plt
from pathlib import Path
import time
from datetime import datetime
import pandas as pd
import xarray as xr

def find_src_rrs3c(start_dir=Path.cwd(), max_parents=8):
    p = start_dir.resolve()
    for _ in range(max_parents + 1):
        candidate = p / "src" / "rrs3c"
        if candidate.exists() and (candidate / "model.py").exists():
            return (p / "src").resolve()
        p = p.parent
    return None

src_dir = find_src_rrs3c()
print("Notebook working dir:", Path.cwd())

if src_dir is None:
    raise RuntimeError("Could not find src/rrs3c. Make sure the notebook is inside the repository.")

repo_root = src_dir.parent
sys.path.insert(0, str(src_dir))
sys.path.insert(0, str(repo_root))
print("Repository root added to path:", repo_root)

from rrs3c.model import rrs_model_3C_O25
print('Successfully imported rrs_model_3C_O25')
# Out:
# Notebook working dir: C:\Users\Jaime\Documents\GitHub\3C-Rrs-O25\notebooks
# Repository root added to path: C:\Users\Jaime\Documents\GitHub\3C-Rrs-O25
# Successfully imported rrs_model_3C_O25

# %% [markdown]
# ## Load raw Jetty data (example CSV)
# If your CSV is in `examples/example_time_series_data.csv` the loader below will read it. Otherwise adjust the path.

# %%
from examples.timeseries.src.utils import load_jetty_data, solar_az_el, flags_jetty

# Use repo_root from the previous cell (if you want to keep it in scope, you may need to make it global or recompute)
# For simplicity, recompute repo_root:
repo_root = Path(find_src_rrs3c()).parent
infile = repo_root / "examples" / "timeseries" / "data" / 'example_time_series_data.csv'

if not infile.exists():
    raise FileNotFoundError(f"Data file not found at {infile}. Please place it there or adjust the path.")

instrument, variable, times, l1, l_end, delta_l, spec = load_jetty_data(str(infile))
print('Loaded raw:', spec.shape, 'spectra')
# Out:
# Loaded raw: (144, 634) spectra

# %% [markdown]
# ## Convert times to pandas datetime and factorize into unique slots

# %%
times_pd = pd.to_datetime(times, format='%Y%m%d %H%M%S')
idx_inv, uniques = pd.factorize(times_pd)
unique_times = uniques.to_pydatetime()
anc = (4, 60, 1013.25)
N = len(unique_times)
wl = np.arange(350, 921)
nl = len(wl)

# %% [markdown]
# ## Pre-allocate matrices for Es, Li, Lt, Rrs, etc.

# %%
Es_mat = np.full((N, nl), np.nan)
Li_east = np.full((N, nl), np.nan)
Lt_east = np.full((N, nl), np.nan)
Rrs_east = np.full((N, nl), np.nan)
Rrs_mod_east = np.full((N, nl), np.nan)
Rg_east = np.full((N, nl), np.nan)

Li_west = np.full((N, nl), np.nan)
Lt_west = np.full((N, nl), np.nan)
Rrs_west = np.full((N, nl), np.nan)
Rrs_mod_west = np.full((N, nl), np.nan)
Rg_west = np.full((N, nl), np.nan)

# %% [markdown]
# ## Diagnostics and storage for fit objects (initialized before the loop)

# %%
idx550 = np.argmin(np.abs(wl - 550))
resid_rmse_east = np.full(N, np.nan)
resid_rmse_west = np.full(N, np.nan)
resid550_east = np.full(N, np.nan)
resid550_west = np.full(N, np.nan)
rho_east = np.full(N, np.nan)
rho_d_east = np.full(N, np.nan)
rho_s_east = np.full(N, np.nan)
rho_west = np.full(N, np.nan)
rho_d_west = np.full(N, np.nan)
rho_s_west = np.full(N, np.nan)
Rg550_east = np.full(N, np.nan)
Rg550_west = np.full(N, np.nan)

# Lists to keep whole fit Result objects for later inspection
res_east_list = [None] * N
res_west_list = [None] * N

# %% [markdown]
# # Build 3C model instance
# ## Model is instantiated outside the loop

# %%
model = rrs_model_3C_O25()  # use default data_folder or override as needed

# %% [markdown]
# ## Loop

# %%
start_time = time.time()
# Loop over unique time bins
for i, t0 in enumerate(unique_times):
    mask = idx_inv == i
    vars_i = variable[mask]

    # select Es tag
    if 'ES' in vars_i:
        tag_es = 'ES'
    elif 'ES-VIS' in vars_i:
        tag_es = 'ES-VIS'
    else:
        continue

    # Extract Es spectrum and interpolate to global wl
    idx_es = np.where((variable == tag_es) & mask)[0]
    l_start, l_stop = float(l1[idx_es[0]]), float(l_end[idx_es[0]])
    raw = spec[idx_es, :int(l_stop - l_start + 1)][0]
    # build local wavelength axis for this spectrum
    wl_row = np.linspace(l_start, l_stop, raw.size)
    # interpolate onto global wl grid
    Es_interp = np.interp(wl, wl_row, raw)
    Es_mat[i, :] = Es_interp

    # Flag dark/red
    dark, red, anom= flags_jetty(wl, Es_interp)
    # Compute solar position
    Az, El = solar_az_el(t0, lat=53.001788, lon=4.789151)

    if not dark and not red and El >= 5:
        # process east and west
        for side in ('EAST', 'WEST'):
            sky_tag = f'LSKY-{side}'
            surf_tag = f'LSFC-{side}'
            if sky_tag in vars_i and surf_tag in vars_i:
                # extract raw Li, Lt
                idx_ls = np.where((variable == sky_tag) & mask)[0]
                idx_lu = np.where((variable == surf_tag) & mask)[0]
                raw_Li = spec[idx_ls, :int(l_stop - l_start + 1)][0]
                raw_Lt = spec[idx_lu, :int(l_stop - l_start + 1)][0]

                # build local wavelength axis and interpolate to global wl
                wl_row = np.linspace(l_start, l_stop, raw_Li.size)
                Li_interp = np.interp(wl, wl_row, raw_Li)
                Lt_interp = np.interp(wl, wl_row, raw_Lt)

                # store interpolated spectra
                # fit 3C model
                params = lm.Parameters()
                
                # O25
                params.add_many(
                    ('C', 5, True, 0.1, 50, None),
                    ('N', 1, True, 0.01, 100, None),
                    ('Y', 0.5, True, 0.01, 5, None),
                    ('SNAP', 0.015, True, 0.005, 0.03, None),
                    ('Sg', 0.015, True, 0.005, 0.03, None),
                    ('rho', 0.02, True, 0, 0.03, None),
                    ('rho_d', 0.0, True, 0, 10, None),
                    ('rho_s', 0.01, True, -.1, .1, None),
                    ('delta', 0.0, False, -0.01, 0.01, None),
                    ('alpha', 0.2, True, 0, 2, None),
                    ('beta', 0.05, True, 0, 1, None)
                )
                
                

                weights = np.where((wl >= 750) & (wl <= 775), 0, # Remove the ugly H2O feature
                    np.where(wl < 400, 1, # Some potential troubles at the UV
                    np.where(wl > 800, 5, 1))) # Let's power-up the NIR


                geom = (90 - El, 35, abs(Az - (135 if side == 'EAST' else 225)))                
                # call fit_Ltes with interpolated spectra
                res, Rrs_mod, Rg = model.fit_LtEs(
                    wl, Li_interp/Es_interp, Lt_interp/Es_interp, 
                    params, weights, geom, anc
                )
                LtEs_obs = Lt_interp/Es_interp
                LtEs_mod = Rrs_mod + Rg

                # Compute residual in Lt/Es space as requested by the user
                # resid_vec = LtEs_mod - LtEs_obs
                resid_vec = LtEs_mod - LtEs_obs
                rmse_val = np.sqrt(np.nanmean((resid_vec)**2))
                resid550_val = resid_vec[idx550]

                # Observed and modelled Rrs (Lt/Es - Rg)
                Rrs_obs = LtEs_obs - Rg
                
                # Store into pre-allocated arrays and diagnostics
                if side == 'EAST':
                    Li_east[i, :] = Li_interp
                    Lt_east[i, :] = Lt_interp
                    Rrs_east[i, :] = Rrs_obs
                    Rrs_mod_east[i, :] = Rrs_mod
                    Rg_east[i, :] = Rg

                    resid_rmse_east[i] = rmse_val
                    resid550_east[i] = resid550_val
                    Rg550_east[i] = Rg[idx550]

                    # save fitted parameter values safely
                    try:
                        rho_east[i] = res.params['rho_s'].value
                        rho_d_east[i] = res.params['rho_d'].value
                        rho_s_east[i] = res.params['rho_s'].value
                    except Exception:
                        pass

                    # save full Result object for later inspection
                    res_east_list[i] = res

                else:  # WEST
                    Li_west[i, :] = Li_interp
                    Lt_west[i, :] = Lt_interp
                    Rrs_west[i, :] = Rrs_obs
                    Rrs_mod_west[i, :] = Rrs_mod
                    Rg_west[i, :] = Rg

                    resid_rmse_west[i] = rmse_val
                    resid550_west[i] = resid550_val
                    Rg550_west[i] = Rg[idx550]

                    try:
                        rho_west[i] = res.params['rho_s'].value
                        rho_d_west[i] = res.params['rho_d'].value
                        rho_s_west[i] = res.params['rho_s'].value
                    except Exception:
                        pass

                    res_west_list[i] = res


end_time = time.time()
elapsed_time = end_time - start_time  # in seconds
# Out:
# message: Fit succeeded.
# ier: 2
# nfev: 670
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=0.617894 ± 0.00119   min=0.1   max=50   vary=True
# N            value=3.12813 ± 0.219   min=0.01   max=100   vary=True
# Y            value=0.560281 ± 0.101   min=0.01   max=5   vary=True
# SNAP         value=0.0119631 ± 0.612   min=0.005   max=0.03   vary=True
# Sg           value=0.0121191 ± 0.0761   min=0.005   max=0.03   vary=True
# rho          value=1.40584e-09 ± 0.00012   min=0   max=0.03   vary=True
# rho_d        value=0.265131 ± 0.0474   min=0   max=10   vary=True
# rho_s        value=0.0774587 ± 0.00384   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.277761 ± 0.215   min=0   max=2   vary=True
# beta         value=0.283235 ± 0.218   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 393
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89764 ± 0.482   min=0.1   max=50   vary=True
# N            value=2.47241 ± 0.0605   min=0.01   max=100   vary=True
# Y            value=0.509063 ± 0.0433   min=0.01   max=5   vary=True
# SNAP         value=0.0299989 ± 0.00756   min=0.005   max=0.03   vary=True
# Sg           value=0.0127777 ± 0.000624   min=0.005   max=0.03   vary=True
# rho          value=0.0221169 ± 0.0179   min=0   max=0.03   vary=True
# rho_d        value=0.00080584 ± 0.000438   min=0   max=10   vary=True
# rho_s        value=0.0131218 ± 0.0227   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.99927 ± 3.27   min=0   max=2   vary=True
# beta         value=0.0318118 ± 0.0495   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 187
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=14.5111 ± 1.93   min=0.1   max=50   vary=True
# N            value=3.59705 ± 0.485   min=0.01   max=100   vary=True
# Y            value=0.366982 ± 0.276   min=0.01   max=5   vary=True
# SNAP         value=0.00500612 ± 0.000622   min=0.005   max=0.03   vary=True
# Sg           value=0.0299803 ± 0.00554   min=0.005   max=0.03   vary=True
# rho          value=0.0115773 ± 0.0172   min=0   max=0.03   vary=True
# rho_d        value=0.704965 ± 0.234   min=0   max=10   vary=True
# rho_s        value=0.0875386 ± 0.0432   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.160207 ± 0.0834   min=0   max=2   vary=True
# beta         value=0.676693 ± 0.311   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 393
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89764 ± 0.468   min=0.1   max=50   vary=True
# N            value=2.5745 ± 0.0619   min=0.01   max=100   vary=True
# Y            value=0.501629 ± 0.0393   min=0.01   max=5   vary=True
# SNAP         value=0.03 ± 0.00685   min=0.005   max=0.03   vary=True
# Sg           value=0.0123639 ± 0.000589   min=0.005   max=0.03   vary=True
# rho          value=0.0211825 ± 0.0172   min=0   max=0.03   vary=True
# rho_d        value=0.00115641 ± 0.000443   min=0   max=10   vary=True
# rho_s        value=0.0114579 ± 0.022   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.99842 ± 3.25   min=0   max=2   vary=True
# beta         value=0.038131 ± 0.064   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 537
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=0.77267 ± 1.19   min=0.1   max=50   vary=True
# N            value=2.48417 ± 0.152   min=0.01   max=100   vary=True
# Y            value=0.683497 ± 0.205   min=0.01   max=5   vary=True
# SNAP         value=0.0146785 ± 35.6   min=0.005   max=0.03   vary=True
# Sg           value=0.0146836 ± 3.31   min=0.005   max=0.03   vary=True
# rho          value=0.03 ± 0.0152   min=0   max=0.03   vary=True
# rho_d        value=0.311575 ± 0.00437   min=0   max=10   vary=True
# rho_s        value=0.0448145 ± 0.0332   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2 ± 1.27   min=0   max=2   vary=True
# beta         value=0.0225893 ± 0.02   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 200
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.8976 ± 5.19e-05   min=0.1   max=50   vary=True
# N            value=2.47307 ± 0.0561   min=0.01   max=100   vary=True
# Y            value=0.465879 ± 0.068   min=0.01   max=5   vary=True
# SNAP         value=0.00818826 ± 0.00227   min=0.005   max=0.03   vary=True
# Sg           value=0.0154982 ± 0.00227   min=0.005   max=0.03   vary=True
# rho          value=0.0145751 ± 0.0131   min=0   max=0.03   vary=True
# rho_d        value=0.00210326 ± 0.00074   min=0   max=10   vary=True
# rho_s        value=0.0195213 ± 0.0159   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.99998 ± 5.31   min=0   max=2   vary=True
# beta         value=0.0372173 ± 0.0268   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 439
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=1.21129 ± 1.28   min=0.1   max=50   vary=True
# N            value=2.09251 ± 0.099   min=0.01   max=100   vary=True
# Y            value=0.861182 ± 0.228   min=0.01   max=5   vary=True
# SNAP         value=0.0204336 ± 0.106   min=0.005   max=0.03   vary=True
# Sg           value=0.0175157 ± 0.00421   min=0.005   max=0.03   vary=True
# rho          value=0.029832 ± 0.0174   min=0   max=0.03   vary=True
# rho_d        value=0.256935 ± 0.0227   min=0   max=10   vary=True
# rho_s        value=0.00705195 ± 0.0324   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.312724 ± 1.89e+04   min=0   max=2   vary=True
# beta         value=1.60133e-06 ± 0.0739   min=0   max=1   vary=True
# message: Fit succeeded. Could not estimate error-bars.
# ier: 1
# nfev: 20589
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=5.92804   min=0.1   max=50   vary=True
# N            value=2.33774   min=0.01   max=100   vary=True
# Y            value=0.509872   min=0.01   max=5   vary=True
# SNAP         value=0.03   min=0.005   max=0.03   vary=True
# Sg           value=0.0127819   min=0.005   max=0.03   vary=True
# rho          value=0.0142527   min=0   max=0.03   vary=True
# rho_d        value=0.00140668   min=0   max=10   vary=True
# rho_s        value=0.0241665   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2   min=0   max=2   vary=True
# beta         value=0.0460311   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 418
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=19.827 ± 1.1   min=0.1   max=50   vary=True
# N            value=3.72866 ± 0.249   min=0.01   max=100   vary=True
# Y            value=0.296795 ± 0.106   min=0.01   max=5   vary=True
# SNAP         value=0.00500034 ± 0.000349   min=0.005   max=0.03   vary=True
# Sg           value=0.0298768 ± 0.00295   min=0.005   max=0.03   vary=True
# rho          value=0.0298938 ± 0.0196   min=0   max=0.03   vary=True
# rho_d        value=0.150088 ± 0.0309   min=0   max=10   vary=True
# rho_s        value=0.0121169 ± 0.0381   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.046e-07 ± 0.523   min=0   max=2   vary=True
# beta         value=0.0469818 ± 0.193   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 314
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=8.04368 ± 0.622   min=0.1   max=50   vary=True
# N            value=2.29066 ± 0.0784   min=0.01   max=100   vary=True
# Y            value=0.413077 ± 0.0464   min=0.01   max=5   vary=True
# SNAP         value=0.0299998 ± 0.00666   min=0.005   max=0.03   vary=True
# Sg           value=0.0126669 ± 0.000892   min=0.005   max=0.03   vary=True
# rho          value=0.0207848 ± 0.0193   min=0   max=0.03   vary=True
# rho_d        value=0.00790602 ± 0.00113   min=0   max=10   vary=True
# rho_s        value=0.0165005 ± 0.026   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.45752 ± 1.25   min=0   max=2   vary=True
# beta         value=0.249313 ± 0.725   min=0   max=1   vary=True
# message: Fit succeeded. Could not estimate error-bars.
# ier: 1
# nfev: 4509
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=9.74432   min=0.1   max=50   vary=True
# N            value=5.40118   min=0.01   max=100   vary=True
# Y            value=0.342416   min=0.01   max=5   vary=True
# SNAP         value=0.03   min=0.005   max=0.03   vary=True
# Sg           value=0.005   min=0.005   max=0.03   vary=True
# rho          value=4.62642e-13   min=0   max=0.03   vary=True
# rho_d        value=0.0497161   min=0   max=10   vary=True
# rho_s        value=0.0633431   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.14103   min=0   max=2   vary=True
# beta         value=0.999997   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 394
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89766 ± 0.974   min=0.1   max=50   vary=True
# N            value=1.82519 ± 0.083   min=0.01   max=100   vary=True
# Y            value=0.500581 ± 0.119   min=0.01   max=5   vary=True
# SNAP         value=0.03 ± 0.026   min=0.005   max=0.03   vary=True
# Sg           value=0.0147657 ± 0.00148   min=0.005   max=0.03   vary=True
# rho          value=0.0169258 ± 0.0246   min=0   max=0.03   vary=True
# rho_d        value=0.0113167 ± 0.0637   min=0   max=10   vary=True
# rho_s        value=0.0238765 ± 0.0347   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2.21211e-11 ± 0.0438   min=0   max=2   vary=True
# beta         value=0.49837 ± 6.02   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 525
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=10.4573 ± 0.542   min=0.1   max=50   vary=True
# N            value=3.66439 ± 0.123   min=0.01   max=100   vary=True
# Y            value=0.274097 ± 0.0149   min=0.01   max=5   vary=True
# SNAP         value=0.0299596 ± 0.00161   min=0.005   max=0.03   vary=True
# Sg           value=0.00612963 ± 0.000541   min=0.005   max=0.03   vary=True
# rho          value=2.66845e-07 ± 0.0108   min=0   max=0.03   vary=True
# rho_d        value=0.051402 ± 0.00559   min=0   max=10   vary=True
# rho_s        value=0.0576342 ± 0.0177   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.885318 ± 1.3   min=0   max=2   vary=True
# beta         value=0.998901 ± 4.01   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 347
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=3.87371 ± 0.000199   min=0.1   max=50   vary=True
# N            value=2.20188 ± 0.0844   min=0.01   max=100   vary=True
# Y            value=0.507194 ± 0.112   min=0.01   max=5   vary=True
# SNAP         value=0.0135431 ± 0.0664   min=0.005   max=0.03   vary=True
# Sg           value=0.0146162 ± 0.0143   min=0.005   max=0.03   vary=True
# rho          value=0.0168317 ± 0.0162   min=0   max=0.03   vary=True
# rho_d        value=0.0160901 ± 0.0759   min=0   max=10   vary=True
# rho_s        value=0.0242376 ± 0.0219   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.000163301 ± 0.407   min=0   max=2   vary=True
# beta         value=0.641636 ± 8.88   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 152
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=3.57676 ± 0.458   min=0.1   max=50   vary=True
# N            value=2.03674 ± 0.0538   min=0.01   max=100   vary=True
# Y            value=0.466002 ± 0.0664   min=0.01   max=5   vary=True
# SNAP         value=0.0169431 ± 0.0246   min=0.005   max=0.03   vary=True
# Sg           value=0.0144305 ± 0.00225   min=0.005   max=0.03   vary=True
# rho          value=0.0227959 ± 0.00875   min=0   max=0.03   vary=True
# rho_d        value=0.0801405 ± 0.00716   min=0   max=10   vary=True
# rho_s        value=0.0221883 ± 0.0142   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.621681 ± 395   min=0   max=2   vary=True
# beta         value=0.000229003 ± 0.1   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 302
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89764 ± 0.737   min=0.1   max=50   vary=True
# N            value=2.47751 ± 0.0989   min=0.01   max=100   vary=True
# Y            value=0.524945 ± 0.074   min=0.01   max=5   vary=True
# SNAP         value=0.0284337 ± 0.0122   min=0.005   max=0.03   vary=True
# Sg           value=0.0132744 ± 0.000995   min=0.005   max=0.03   vary=True
# rho          value=0.0127252 ± 0.0207   min=0   max=0.03   vary=True
# rho_d        value=0.0118308 ± 0.0024   min=0   max=10   vary=True
# rho_s        value=0.0261889 ± 0.0265   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.35772 ± 0.831   min=0   max=2   vary=True
# beta         value=0.724056 ± 1.62   min=0   max=1   vary=True
# message: Fit succeeded. Could not estimate error-bars.
# ier: 1
# nfev: 2377
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=5.52906   min=0.1   max=50   vary=True
# N            value=2.95584   min=0.01   max=100   vary=True
# Y            value=0.495706   min=0.01   max=5   vary=True
# SNAP         value=0.005   min=0.005   max=0.03   vary=True
# Sg           value=0.0186599   min=0.005   max=0.03   vary=True
# rho          value=4.62642e-13   min=0   max=0.03   vary=True
# rho_d        value=0.0555418   min=0   max=10   vary=True
# rho_s        value=0.0596319   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.87552   min=0   max=2   vary=True
# beta         value=1   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 437
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=8.04366 ± 2.78   min=0.1   max=50   vary=True
# N            value=1.37743 ± 0.191   min=0.01   max=100   vary=True
# Y            value=0.884434 ± 0.286   min=0.01   max=5   vary=True
# SNAP         value=0.0063578 ± 0.00212   min=0.005   max=0.03   vary=True
# Sg           value=0.0299626 ± 0.00621   min=0.005   max=0.03   vary=True
# rho          value=4.34518e-07 ± 0.0374   min=0   max=0.03   vary=True
# rho_d        value=0.062681 ± 0.307   min=0   max=10   vary=True
# rho_s        value=0.0559947 ± 0.0534   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.00794738 ± 1.08   min=0   max=2   vary=True
# beta         value=0.996195 ± 51.8   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 428
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89763 ± 0.282   min=0.1   max=50   vary=True
# N            value=2.20419 ± 0.0321   min=0.01   max=100   vary=True
# Y            value=0.383119 ± 0.0347   min=0.01   max=5   vary=True
# SNAP         value=0.00659322 ± 0.000754   min=0.005   max=0.03   vary=True
# Sg           value=0.0163192 ± 0.00107   min=0.005   max=0.03   vary=True
# rho          value=0.0121965 ± 0.00429   min=0   max=0.03   vary=True
# rho_d        value=0.0152695 ± 0.053   min=0   max=10   vary=True
# rho_s        value=0.0303569 ± 0.00642   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.000476328 ± 0.0701   min=0   max=2   vary=True
# beta         value=0.855409 ± 3.4   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 424
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=1.07496 ± 0.000622   min=0.1   max=50   vary=True
# N            value=2.84299 ± 0.162   min=0.01   max=100   vary=True
# Y            value=0.534893 ± 0.0837   min=0.01   max=5   vary=True
# SNAP         value=0.0119975 ± 0.12   min=0.005   max=0.03   vary=True
# Sg           value=0.0124777 ± 0.0196   min=0.005   max=0.03   vary=True
# rho          value=0.0252204 ± 0.0237   min=0   max=0.03   vary=True
# rho_d        value=0.0475363 ± 0.0101   min=0   max=10   vary=True
# rho_s        value=0.0245055 ± 0.0276   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.3455 ± 1.38   min=0   max=2   vary=True
# beta         value=0.997488 ± 1.5   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 465
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=4.94752 ± 3.15e-05   min=0.1   max=50   vary=True
# N            value=2.13774 ± 0.0351   min=0.01   max=100   vary=True
# Y            value=0.465566 ± 0.023   min=0.01   max=5   vary=True
# SNAP         value=0.03 ± 0.00538   min=0.005   max=0.03   vary=True
# Sg           value=0.0138537 ± 0.000374   min=0.005   max=0.03   vary=True
# rho          value=0.017456 ± 0.00632   min=0   max=0.03   vary=True
# rho_d        value=0.0228051 ± 0.00253   min=0   max=10   vary=True
# rho_s        value=0.0211702 ± 0.00943   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.976358 ± 2.76   min=0   max=2   vary=True
# beta         value=0.699341 ± 5.43   min=0   max=1   vary=True
# message: Tolerance seems to be too small. Could not estimate error-bars.
# ier: -1
# nfev: 22000
# success: False
# MINPACK ier: -1 - unknown / user-requested stop.
#
# Optimized parameters:
# C            value=14.7793   min=0.1   max=50   vary=True
# N            value=2.49309   min=0.01   max=100   vary=True
# Y            value=0.332266   min=0.01   max=5   vary=True
# SNAP         value=0.00500002   min=0.005   max=0.03   vary=True
# Sg           value=0.03   min=0.005   max=0.03   vary=True
# rho          value=0.00215347   min=0   max=0.03   vary=True
# rho_d        value=0.0782653   min=0   max=10   vary=True
# rho_s        value=0.0536876   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=9.80652e-08   min=0   max=2   vary=True
# beta         value=0.30696   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 371
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=4.2449 ± 0.254   min=0.1   max=50   vary=True
# N            value=2.22042 ± 0.0301   min=0.01   max=100   vary=True
# Y            value=0.440845 ± 0.0304   min=0.01   max=5   vary=True
# SNAP         value=0.0102637 ± 0.00176   min=0.005   max=0.03   vary=True
# Sg           value=0.0157766 ± 0.00107   min=0.005   max=0.03   vary=True
# rho          value=0.0185471 ± 0.0055   min=0   max=0.03   vary=True
# rho_d        value=0.00836879 ± 0.00423   min=0   max=10   vary=True
# rho_s        value=0.0151232 ± 0.00826   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.687733 ± 1.93   min=0   max=2   vary=True
# beta         value=0.284037 ± 0.637   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 405
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=8.0437 ± 1.31   min=0.1   max=50   vary=True
# N            value=4.35206 ± 0.499   min=0.01   max=100   vary=True
# Y            value=0.175091 ± 0.0891   min=0.01   max=5   vary=True
# SNAP         value=0.00682839 ± 1.21   min=0.005   max=0.03   vary=True
# Sg           value=0.00680093 ± 1.16   min=0.005   max=0.03   vary=True
# rho          value=0.00237551 ± 0.0444   min=0   max=0.03   vary=True
# rho_d        value=0.108662 ± 0.0996   min=0   max=10   vary=True
# rho_s        value=0.0159661 ± 0.0847   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.159334 ± 0.427   min=0   max=2   vary=True
# beta         value=0.399894 ± 1.33   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 348
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89752 ± 2.47e-05   min=0.1   max=50   vary=True
# N            value=1.77371 ± 0.0357   min=0.01   max=100   vary=True
# Y            value=0.493283 ± 0.0377   min=0.01   max=5   vary=True
# SNAP         value=0.023097 ± 0.00739   min=0.005   max=0.03   vary=True
# Sg           value=0.0161443 ± 0.000362   min=0.005   max=0.03   vary=True
# rho          value=0.0115178 ± 0.00595   min=0   max=0.03   vary=True
# rho_d        value=0.0144769 ± 0.00208   min=0   max=10   vary=True
# rho_s        value=0.0238038 ± 0.00792   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.2137 ± 0.645   min=0   max=2   vary=True
# beta         value=0.806114 ± 0.847   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 348
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=0.521765 ± 1.17   min=0.1   max=50   vary=True
# N            value=4.09619 ± 0.491   min=0.01   max=100   vary=True
# Y            value=0.545763 ± 0.251   min=0.01   max=5   vary=True
# SNAP         value=0.0107258 ± 0.462   min=0.005   max=0.03   vary=True
# Sg           value=0.0104602 ± 0.0573   min=0.005   max=0.03   vary=True
# rho          value=0.0227937 ± 0.0463   min=0   max=0.03   vary=True
# rho_d        value=0.108812 ± 0.00861   min=0   max=10   vary=True
# rho_s        value=0.0353742 ± 0.0669   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.67174 ± 1.19   min=0   max=2   vary=True
# beta         value=0.265226 ± 0.205   min=0   max=1   vary=True
# message: Fit succeeded. Could not estimate error-bars.
# ier: 1
# nfev: 7826
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=11.8429   min=0.1   max=50   vary=True
# N            value=1.57939   min=0.01   max=100   vary=True
# Y            value=0.404902   min=0.01   max=5   vary=True
# SNAP         value=0.03   min=0.005   max=0.03   vary=True
# Sg           value=0.0147063   min=0.005   max=0.03   vary=True
# rho          value=0.03   min=0   max=0.03   vary=True
# rho_d        value=0.0196963   min=0   max=10   vary=True
# rho_s        value=0.00060858   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.214207   min=0   max=2   vary=True
# beta         value=0.999995   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 143
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=4.95727 ± 2.75   min=0.1   max=50   vary=True
# N            value=4.69401 ± 0.762   min=0.01   max=100   vary=True
# Y            value=0.68278 ± 0.498   min=0.01   max=5   vary=True
# SNAP         value=0.00502218 ± 0.00419   min=0.005   max=0.03   vary=True
# Sg           value=0.0158577 ± 0.00777   min=0.005   max=0.03   vary=True
# rho          value=5.18493e-10 ± 0.11   min=0   max=0.03   vary=True
# rho_d        value=0.263302 ± 0.507   min=0   max=10   vary=True
# rho_s        value=0.0759373 ± 0.11   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.311294 ± 0.888   min=0   max=2   vary=True
# beta         value=0.948007 ± 2.97   min=0   max=1   vary=True
# message: Fit succeeded. Could not estimate error-bars.
# ier: 1
# nfev: 8858
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=14.4571   min=0.1   max=50   vary=True
# N            value=1.32936   min=0.01   max=100   vary=True
# Y            value=0.456658   min=0.01   max=5   vary=True
# SNAP         value=0.0172428   min=0.005   max=0.03   vary=True
# Sg           value=0.0172424   min=0.005   max=0.03   vary=True
# rho          value=0.03   min=0   max=0.03   vary=True
# rho_d        value=0.0210272   min=0   max=10   vary=True
# rho_s        value=-0.00146869   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.0509734   min=0   max=2   vary=True
# beta         value=0.999966   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 1791
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=10.4573 ± 2.92   min=0.1   max=50   vary=True
# N            value=3.93789 ± 0.467   min=0.01   max=100   vary=True
# Y            value=1.02722 ± 1.3   min=0.01   max=5   vary=True
# SNAP         value=0.0178044 ± 0.422   min=0.005   max=0.03   vary=True
# Sg           value=0.0164876 ± 0.0471   min=0.005   max=0.03   vary=True
# rho          value=0.0289696 ± 0.0465   min=0   max=0.03   vary=True
# rho_d        value=0.115058 ± 0.101   min=0   max=10   vary=True
# rho_s        value=0.0132142 ± 0.0792   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=8.29034e-05 ± 1.29   min=0   max=2   vary=True
# beta         value=0.0442076 ± 0.906   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 249
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=13.2081 ± 2.69e-05   min=0.1   max=50   vary=True
# N            value=1.2387 ± 0.0471   min=0.01   max=100   vary=True
# Y            value=0.434156 ± 0.0647   min=0.01   max=5   vary=True
# SNAP         value=0.0263129 ± 0.0136   min=0.005   max=0.03   vary=True
# Sg           value=0.0164579 ± 0.00107   min=0.005   max=0.03   vary=True
# rho          value=0.0229101 ± 0.0124   min=0   max=0.03   vary=True
# rho_d        value=0.00703137 ± 0.00959   min=0   max=10   vary=True
# rho_s        value=0.0153051 ± 0.0185   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.172577 ± 1.49   min=0   max=2   vary=True
# beta         value=0.139188 ± 1.2   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 742
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=10.4572 ± 0.000672   min=0.1   max=50   vary=True
# N            value=7.15751 ± 1.48   min=0.01   max=100   vary=True
# Y            value=0.442152 ± 0.347   min=0.01   max=5   vary=True
# SNAP         value=0.005 ± 0.00748   min=0.005   max=0.03   vary=True
# Sg           value=0.00915333 ± 0.0126   min=0.005   max=0.03   vary=True
# rho          value=4.6276e-13 ± 15.6   min=0   max=0.03   vary=True
# rho_d        value=0.17222 ± 0.0735   min=0   max=10   vary=True
# rho_s        value=0.0260763 ± 0.0247   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=3.85022e-09 ± 1.09   min=0   max=2   vary=True
# beta         value=0.267895 ± 0.504   min=0   max=1   vary=True
# message: Tolerance seems to be too small. Could not estimate error-bars.
# ier: -1
# nfev: 22000
# success: False
# MINPACK ier: -1 - unknown / user-requested stop.
#
# Optimized parameters:
# C            value=14.8695   min=0.1   max=50   vary=True
# N            value=1.16492   min=0.01   max=100   vary=True
# Y            value=0.609602   min=0.01   max=5   vary=True
# SNAP         value=0.019597   min=0.005   max=0.03   vary=True
# Sg           value=0.0195961   min=0.005   max=0.03   vary=True
# rho          value=0.0115353   min=0   max=0.03   vary=True
# rho_d        value=0.00257138   min=0   max=10   vary=True
# rho_s        value=0.0218266   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2   min=0   max=2   vary=True
# beta         value=0.159441   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 195
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=24.2018 ± 3.23   min=0.1   max=50   vary=True
# N            value=11.0729 ± 2.04   min=0.01   max=100   vary=True
# Y            value=0.721346 ± 0.0955   min=0.01   max=5   vary=True
# SNAP         value=0.0299933 ± 0.00862   min=0.005   max=0.03   vary=True
# Sg           value=0.00500044 ± 0.00139   min=0.005   max=0.03   vary=True
# rho          value=0.0050279 ± 0.0198   min=0   max=0.03   vary=True
# rho_d        value=0.144522 ± 0.00745   min=0   max=10   vary=True
# rho_s        value=0.0640394 ± 0.036   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.78596 ± 6.88   min=0   max=2   vary=True
# beta         value=0.029649 ± 0.103   min=0   max=1   vary=True
# message: Tolerance seems to be too small. Could not estimate error-bars.
# ier: -1
# nfev: 22000
# success: False
# MINPACK ier: -1 - unknown / user-requested stop.
#
# Optimized parameters:
# C            value=15.3104   min=0.1   max=50   vary=True
# N            value=1.09816   min=0.01   max=100   vary=True
# Y            value=0.630385   min=0.01   max=5   vary=True
# SNAP         value=0.0196871   min=0.005   max=0.03   vary=True
# Sg           value=0.0196851   min=0.005   max=0.03   vary=True
# rho          value=0.00894682   min=0   max=0.03   vary=True
# rho_d        value=0.00399686   min=0   max=10   vary=True
# rho_s        value=0.0261607   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.99997   min=0   max=2   vary=True
# beta         value=0.158946   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 578
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.8976 ± 0.000585   min=0.1   max=50   vary=True
# N            value=7.43912 ± 1.65   min=0.01   max=100   vary=True
# Y            value=0.401931 ± 0.296   min=0.01   max=5   vary=True
# SNAP         value=0.00500001 ± 0.0169   min=0.005   max=0.03   vary=True
# Sg           value=0.00735119 ± 0.0174   min=0.005   max=0.03   vary=True
# rho          value=9.15275e-10 ± 0.0484   min=0   max=0.03   vary=True
# rho_d        value=0.17089 ± 0.018   min=0   max=10   vary=True
# rho_s        value=0.0557333 ± 0.0868   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2 ± 648   min=0   max=2   vary=True
# beta         value=0.0947561 ± 0.069   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 1628
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=17.9846 ± 0.835   min=0.1   max=50   vary=True
# N            value=1.29224 ± 0.0768   min=0.01   max=100   vary=True
# Y            value=0.797568 ± 0.231   min=0.01   max=5   vary=True
# SNAP         value=0.0203332 ± 2.17   min=0.005   max=0.03   vary=True
# Sg           value=0.0202465 ± 0.162   min=0.005   max=0.03   vary=True
# rho          value=0.0150761 ± 0.0136   min=0   max=0.03   vary=True
# rho_d        value=0.00229862 ± 0.000892   min=0   max=10   vary=True
# rho_s        value=0.017489 ± 0.0158   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.99994 ± 0.811   min=0   max=2   vary=True
# beta         value=0.303014 ± 0.293   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 659
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=5.89748 ± 0.000573   min=0.1   max=50   vary=True
# N            value=8.22205 ± 1.61   min=0.01   max=100   vary=True
# Y            value=0.296874 ± 0.131   min=0.01   max=5   vary=True
# SNAP         value=0.005 ± 158   min=0.005   max=0.03   vary=True
# Sg           value=0.00500001 ± 0.733   min=0.005   max=0.03   vary=True
# rho          value=0.00726089 ± 0.0364   min=0   max=0.03   vary=True
# rho_d        value=0.195293 ± 0.0179   min=0   max=10   vary=True
# rho_s        value=0.0555436 ± 0.0664   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.75106 ± 0.674   min=0   max=2   vary=True
# beta         value=0.24746 ± 0.048   min=0   max=1   vary=True
# message: Tolerance seems to be too small. Could not estimate error-bars.
# ier: -1
# nfev: 22000
# success: False
# MINPACK ier: -1 - unknown / user-requested stop.
#
# Optimized parameters:
# C            value=14.6244   min=0.1   max=50   vary=True
# N            value=1.42334   min=0.01   max=100   vary=True
# Y            value=0.708679   min=0.01   max=5   vary=True
# SNAP         value=0.0193648   min=0.005   max=0.03   vary=True
# Sg           value=0.0193634   min=0.005   max=0.03   vary=True
# rho          value=0.00445293   min=0   max=0.03   vary=True
# rho_d        value=0.00369347   min=0   max=10   vary=True
# rho_s        value=0.0296643   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.99998   min=0   max=2   vary=True
# beta         value=0.16287   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 312
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=9.15135 ± 2.64   min=0.1   max=50   vary=True
# N            value=7.27841 ± 1.32   min=0.01   max=100   vary=True
# Y            value=0.337256 ± 0.0769   min=0.01   max=5   vary=True
# SNAP         value=0.0299941 ± 0.0052   min=0.005   max=0.03   vary=True
# Sg           value=0.00500016 ± 0.00759   min=0.005   max=0.03   vary=True
# rho          value=0.00395123 ± 0.00093   min=0   max=0.03   vary=True
# rho_d        value=0.196585 ± 0.135   min=0   max=10   vary=True
# rho_s        value=0.0831288 ± 0.0116   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.36633 ± 0.925   min=0   max=2   vary=True
# beta         value=0.39404 ± 1.05   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 1
# nfev: 10406
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=14.7769 ± 0.675   min=0.1   max=50   vary=True
# N            value=1.93615 ± 0.0624   min=0.01   max=100   vary=True
# Y            value=0.730653 ± 0.188   min=0.01   max=5   vary=True
# SNAP         value=0.0181407 ± 1.69e+03   min=0.005   max=0.03   vary=True
# Sg           value=0.0181406 ± 203   min=0.005   max=0.03   vary=True
# rho          value=4.34329e-07 ± 0.0137   min=0   max=0.03   vary=True
# rho_d        value=0.00372667 ± 0.000923   min=0   max=10   vary=True
# rho_s        value=0.0325127 ± 0.0173   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2 ± 0.239   min=0   max=2   vary=True
# beta         value=0.160088 ± 0.0781   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 362
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=40.4514 ± 5.51   min=0.1   max=50   vary=True
# N            value=16.724 ± 3.23   min=0.01   max=100   vary=True
# Y            value=4.51039 ± 24.5   min=0.01   max=5   vary=True
# SNAP         value=0.0257428 ± 0.657   min=0.005   max=0.03   vary=True
# Sg           value=0.0177989 ± 0.00389   min=0.005   max=0.03   vary=True
# rho          value=8.7944e-05 ± 3.88e-05   min=0   max=0.03   vary=True
# rho_d        value=0.112573 ± 0.0668   min=0   max=10   vary=True
# rho_s        value=0.0998592 ± 0.0177   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=1.74834 ± 26.8   min=0   max=2   vary=True
# beta         value=0.648356 ± 3.3   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 11104
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=16.9171 ± 0.607   min=0.1   max=50   vary=True
# N            value=2.83304 ± 0.0949   min=0.01   max=100   vary=True
# Y            value=0.708468 ± 0.073   min=0.01   max=5   vary=True
# SNAP         value=0.0160584 ± 1.13e+03   min=0.005   max=0.03   vary=True
# Sg           value=0.0160582 ± 201   min=0.005   max=0.03   vary=True
# rho          value=4.09532e-07 ± 0.0163   min=0   max=0.03   vary=True
# rho_d        value=0.00224191 ± 0.000641   min=0   max=10   vary=True
# rho_s        value=0.0315381 ± 0.0213   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2 ± 0.765   min=0   max=2   vary=True
# beta         value=0.136817 ± 0.0761   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 118
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=12.3953 ± 2.36   min=0.1   max=50   vary=True
# N            value=10.4887 ± 1.55   min=0.01   max=100   vary=True
# Y            value=0.657431 ± 0.632   min=0.01   max=5   vary=True
# SNAP         value=0.00504724 ± 0.000984   min=0.005   max=0.03   vary=True
# Sg           value=0.0174935 ± 0.00906   min=0.005   max=0.03   vary=True
# rho          value=2.43139e-06 ± 2.26e-05   min=0   max=0.03   vary=True
# rho_d        value=0.242873 ± 0.383   min=0   max=10   vary=True
# rho_s        value=0.099601 ± 0.00993   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.500174 ± 1.56   min=0   max=2   vary=True
# beta         value=0.910843 ± 2.34   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 1
# nfev: 4887
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=20.5234 ± 0.539   min=0.1   max=50   vary=True
# N            value=5.39078 ± 0.155   min=0.01   max=100   vary=True
# Y            value=0.623674 ± 0.106   min=0.01   max=5   vary=True
# SNAP         value=0.0129353 ± 1.54   min=0.005   max=0.03   vary=True
# Sg           value=0.0129529 ± 0.567   min=0.005   max=0.03   vary=True
# rho          value=1.01155e-06 ± 0.0215   min=0   max=0.03   vary=True
# rho_d        value=0.00466685 ± 0.000864   min=0   max=10   vary=True
# rho_s        value=0.0302674 ± 0.0277   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2 ± 5.96   min=0   max=2   vary=True
# beta         value=0.0859159 ± 0.0794   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 2
# nfev: 354
# success: True
# MINPACK ier: 2 - converged: xtol satisfied (small change in parameters).
#
# Optimized parameters:
# C            value=31.8404 ± 1.9   min=0.1   max=50   vary=True
# N            value=23.9575 ± 1.39   min=0.01   max=100   vary=True
# Y            value=0.407954 ± 0.309   min=0.01   max=5   vary=True
# SNAP         value=0.00502139 ± 0.000117   min=0.005   max=0.03   vary=True
# Sg           value=0.029999 ± 1.42   min=0.005   max=0.03   vary=True
# rho          value=0.000596735 ± 3.36e-05   min=0   max=0.03   vary=True
# rho_d        value=0.0420669 ± 0.176   min=0   max=10   vary=True
# rho_s        value=0.071583 ± 0.0176   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.596198 ± 3.7   min=0   max=2   vary=True
# beta         value=0.828061 ± 2.88   min=0   max=1   vary=True
# message: Fit succeeded. Could not estimate error-bars.
# ier: 1
# nfev: 9979
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=21.8532   min=0.1   max=50   vary=True
# N            value=5.89538   min=0.01   max=100   vary=True
# Y            value=0.718582   min=0.01   max=5   vary=True
# SNAP         value=0.03   min=0.005   max=0.03   vary=True
# Sg           value=0.0114188   min=0.005   max=0.03   vary=True
# rho          value=4.89246e-07   min=0   max=0.03   vary=True
# rho_d        value=0.00335936   min=0   max=10   vary=True
# rho_s        value=0.0390749   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=2   min=0   max=2   vary=True
# beta         value=0.0670358   min=0   max=1   vary=True
# message: Fit succeeded.
# ier: 1
# nfev: 3017
# success: True
# MINPACK ier: 1 - converged: ftol satisfied (small relative reduction in sum-of-squares).
#
# Optimized parameters:
# C            value=20.7325 ± 1.77   min=0.1   max=50   vary=True
# N            value=9.80527 ± 0.909   min=0.01   max=100   vary=True
# Y            value=0.652974 ± 0.0777   min=0.01   max=5   vary=True
# SNAP         value=0.03 ± 0.000256   min=0.005   max=0.03   vary=True
# Sg           value=0.0071329 ± 0.00117   min=0.005   max=0.03   vary=True
# rho          value=0.0146096 ± 0.0158   min=0   max=0.03   vary=True
# rho_d        value=0.143242 ± 0.0913   min=0   max=10   vary=True
# rho_s        value=0.0397592 ± 0.03   min=-0.1   max=0.1   vary=True
# delta        value=0   min=-0.01   max=0.01   vary=False
# alpha        value=0.545118 ± 0.47   min=0   max=2   vary=True
# beta         value=1 ± 6   min=0   max=1   vary=True

# %% [markdown]
# ## Save results in netCDF with xarray

# %%
# --- Create xarray Dataset and save to NetCDF ---

# Define coordinates
dates = unique_times  # datetime objects
dims = ("time", "wavelength")
coords = {"time": dates, "wavelength": wl}

# Create Dataset
ds = xr.Dataset(
    {
        "Es": (dims, Es_mat, {"long_name": "Downwelling irradiance Es", "units": "mW m^-2 nm^-1"}),
        "Li_east": (dims, Li_east, {"long_name": "Sky radiance East", "units": "mW m^-2 nm^-1 sr^-1"}),
        "Lt_east": (dims, Lt_east, {"long_name": "Surface radiance East", "units": "mW m^-2 nm^-1 sr^-1"}),
        "Rrs_east": (dims, Rrs_east, {"long_name": "Observed remote sensing reflectance East", "units": "sr^-1"}),
        "Rrs_mod_east": (dims, Rrs_mod_east, {"long_name": "Modeled remote sensing reflectance East", "units": "sr^-1"}),
        "Rg_east": (dims, Rg_east, {"long_name": "Surface-reflected reflectance East (R_g)", "units": "sr^-1"}),
        "Li_west": (dims, Li_west, {"long_name": "Sky radiance West", "units": "mW m^-2 nm^-1 sr^-1"}),
        "Lt_west": (dims, Lt_west, {"long_name": "Surface radiance West", "units": "mW m^-2 nm^-1 sr^-1"}),
        "Rrs_west": (dims, Rrs_west, {"long_name": "Observed remote sensing reflectance West", "units": "sr^-1"}),
        "Rrs_mod_west": (dims, Rrs_mod_west, {"long_name": "Modeled remote sensing reflectance West", "units": "sr^-1"}),
        "Rg_west": (dims, Rg_west, {"long_name": "Surface-reflected reflectance West (R_g)", "units": "sr^-1"})
    },
    coords=coords,
    attrs={
        "title": "Rrs time-series at the",
        "history": f"Created {datetime.now().isoformat()}",
        "references": "Groetsch et al. (2017), Pitarch (2026, in prep.)"
    }
)

# %% [markdown]
# ## A few representative plots

# %%
# Plot Es at 550 nm
plt.figure()
plt.plot(unique_times, Es_mat[:, wl == 550], 'k.-')
plt.ylabel('E_s(550)')
plt.gcf().autofmt_xdate()
plt.grid(True)
plt.show()

# Plot Rrs for East and West at 550 nm over time (existing)
plt.figure()
plt.plot(unique_times, Rrs_east[:, wl == 550], 'b.-', label='East')
plt.plot(unique_times, Rrs_west[:, wl == 550], 'r.-', label='West')
plt.ylabel('Rrs(550) (sr^-1)')
plt.gcf().autofmt_xdate()
plt.legend()
plt.grid(True)
plt.title('Time series of Rrs at 550 nm')
plt.show()

# === Additional diagnostics requested: residuals and fitted coefficients ===
# (The arrays were filled inside the fitting loop.)

# Plot diagnostics in a compact grid: 3 rows x 2 columns
fig, axs = plt.subplots(3, 2, figsize=(14, 10), sharex=True)
# Row 0, col 0: RMSE residuals
axs[0, 0].plot(unique_times, resid_rmse_east, 'b.-', label='East')
axs[0, 0].plot(unique_times, resid_rmse_west, 'r.-', label='West')
axs[0, 0].set_ylabel('RMSE (Lt/Es residual)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Row 0, col 1: Residual at 550 nm
axs[0, 1].plot(unique_times, resid550_east, 'b.-', label='East')
axs[0, 1].plot(unique_times, resid550_west, 'r.-', label='West')
axs[0, 1].set_ylabel('Residual @550 (Lt/Es)')
axs[0, 1].grid(True)

# Row 1, col 0: rho_s
axs[1, 0].plot(unique_times, rho_east, 'b.-', label='rho East')
axs[1, 0].plot(unique_times, rho_west, 'r.-', label='rho West')
axs[1, 0].set_ylabel('rho')
axs[1, 0].grid(True)
axs[1, 0].legend()

# Row 1, col 1: rho_dd
axs[1, 1].plot(unique_times, rho_d_east, 'b.-', label='rho_d East')
axs[1, 1].plot(unique_times, rho_d_west, 'r.-', label='rho_d West')
axs[1, 1].set_ylabel('rho_d')
axs[1, 1].grid(True)
axs[1, 1].legend()

# Row 2, col 0: rho_ds
axs[2, 0].plot(unique_times, rho_s_east, 'b.-', label='rho_s East')
axs[2, 0].plot(unique_times, rho_s_west, 'r.-', label='rho_s West')
axs[2, 0].set_ylabel('rho_s')
axs[2, 0].grid(True)
axs[2, 0].legend()

# Row 2, col 1: Rg @ 550 nm
axs[2, 1].plot(unique_times, Rg550_east, 'b.-', label='Rg@550 East')
axs[2, 1].plot(unique_times, Rg550_west, 'r.-', label='Rg@550 West')
axs[2, 1].set_ylabel('R_g (sr^-1) @550')
axs[2, 1].grid(True)
axs[2, 1].legend()

# X-axis formatting
for ax in axs[-1, :]:
    ax.xaxis.set_tick_params(rotation=30)
fig.tight_layout()
plt.show()
